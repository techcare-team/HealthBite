# %% [markdown]
# <a href="https://colab.research.google.com/github/techcare-team/HealthBite/blob/ML/Scraping_Dataset_Gambar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Install bing image downloader
# !pip install bing-image-downloader

# %%
#Buat directori untuk menyimpan dataset
# !mkdir Food_Dataset

# %%
from bing_image_downloader import downloader

downloader.download('kentang balado', limit=150, output_dir='Food_Dataset', adult_filter_off=True)
# Out:
# [%] Downloading Images to /content/Food_Dataset/kentang balado
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 35 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://manfaatcara.com/wp-content/uploads/2020/02/resep-kentang-balado-830x553.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://i1.wp.com/resepkoki.id/wp-content/uploads/2019/06/Resep-Balado-Kentang.jpg?fit=1536%2C2048&amp;ssl=1
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://resepmasakandapurarie.com/wp-content/uploads/2015/05/Resep-Kentang-Balado-Pete-Mudah.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://www.ranchmarket.co.id/cfind/source/thumb/images/tips-recipe/cover_w770_h440_image---balado-kentang.png
# [%] File Downloaded !
#
# [%] Downloading Image #5 from https://img-global.cpcdn.com/recipes/7021e514d80a64b1/680x482cq70/kentang-balado-foto-resep-utama.jpg
# [%] File Downloaded !
#
# ...

# %%
# !zip -r '/content/Food_Dataset/kentang balado.zip' '/content/Food_Dataset/kentang balado'
# Out:
#   adding: content/Food_Dataset/kentang balado/ (stored 0%)
#   adding: content/Food_Dataset/kentang balado/Image_11.jpg (deflated 0%)
#   adding: content/Food_Dataset/kentang balado/Image_42.jpg (deflated 0%)
#   adding: content/Food_Dataset/kentang balado/Image_58.jpg (deflated 0%)
#   adding: content/Food_Dataset/kentang balado/Image_9.jpg (deflated 0%)
#   adding: content/Food_Dataset/kentang balado/Image_25.jpg (deflated 0%)
#   adding: content/Food_Dataset/kentang balado/Image_40.jpg (deflated 0%)
#   adding: content/Food_Dataset/kentang balado/Image_20.jpg (deflated 0%)
#   adding: content/Food_Dataset/kentang balado/Image_28.png (deflated 0%)
#   adding: content/Food_Dataset/kentang balado/Image_5.jpg (deflated 0%)
#   adding: content/Food_Dataset/kentang balado/Image_12.jpg (deflated 0%)
#   adding: content/Food_Dataset/kentang balado/Image_45.jpg (deflated 0%)
#   adding: content/Food_Dataset/kentang balado/Image_34.jpg (deflated 0%)
# ...
